# %% [markdown]
# ### 연령별, 성별 선호 운동 데이터

# %% [markdown]
# #### 1. 종목명 가져오기

# %%
from supabase import create_client, Client

# ----------------------------------------------------
# 1. Supabase 접속 정보
# ----------------------------------------------------
url = "https://ydqqbjjsriadezcnkbmx.supabase.co"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InlkcXFiampzcmlhZGV6Y25rYm14Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3NTgyNDkzMjEsImV4cCI6MjA3MzgyNTMyMX0.U4-v7a40I2HUXJPb2oANFzqwA0QyEErTFEyrgqXdzeA"

supabase: Client = create_client(url, key)

# ----------------------------------------------------
# 2. 데이터 가져오기 및 리스트 생성
# ----------------------------------------------------
try:
    response = supabase.table('songpa_sports_data').select('ftype_nm').execute()
    
    if response.data:
        all_sports_list = [item['ftype_nm'] for item in response.data]
        
        # ----------------------------------------------------
        # 최종 결과를 'sports_nm' 변수에 바로 할당
        # ----------------------------------------------------
        sports_nm = sorted(list(set(all_sports_list)))
        
        # 결과 확인
        print("✅ 'sports_nm' 변수에 리스트 할당 완료!")
        print(sports_nm)

    else:
        print("⚠️ 데이터를 가져오지 못했습니다.")

except Exception as e:
    print(f"❌ 에러가 발생했습니다: {e}")
# Out:
# ✅ 'sports_nm' 변수에 리스트 할당 완료!
# ['간이운동장', '검도', '게이트볼', '골프', '권투', '농구', '당구', '러닝', '레슬링', '배드민턴', '복싱', '볼링', '사이클', '생활체육관', '수영', '야구', '요가', '유도', '주짓수', '축구', '킥복싱', '탁구', '태권도', '테니스', '풋살', '필라테스', '합기도', '헬스']

# %%
sports_nm
# Out:
# ['간이운동장',
#  '검도',
#  '게이트볼',
#  '골프',
#  '권투',
#  '농구',
#  '당구',
#  '러닝',
#  '레슬링',
#  '배드민턴',
#  '복싱',
#  '볼링',
#  '사이클',
#  '생활체육관',
#  '수영',
#  '야구',
#  '요가',
#  '유도',
#  '주짓수',
#  '축구',
#  '킥복싱',
#  '탁구',
#  '태권도',
#  '테니스',
#  '풋살',
#  '필라테스',
#  '합기도',
#  '헬스']

# %% [markdown]
# #### 2. 성별/연령별 선호 종목 데이터프레임 만들기

# %% [markdown]
# 재미나이 피셜..

# %%
import pandas as pd

# 1. 사용할 리스트 정의
ages = ['10대', '20대', '30대', '40대', '50대', '60대', '70대 이상']
gender = ['남', '여']

# 2. (수정) sports_nm 리스트에 '복싱', '주짓수', '킥복싱' 등 추가
sports_nm_combinations = [
    # 10대 남성 (권투->복싱, 주짓수/킥복싱 추가)
    '축구, 태권도, 야구, 복싱, 풋살, 주짓수, 킥복싱', 
    # 10대 여성 (합기도 추가)
    '태권도, 수영, 배드민턴, 합기도', 
    # 20대 남성 (복싱, 주짓수 추가)
    '헬스, 축구, 당구, 골프, 볼링, 복싱, 주짓수', 
    # 20대 여성 (킥복싱 추가)
    '헬스, 요가, 필라테스, 수영, 테니스, 킥복싱', 
    # 30대 남성 (복싱, 레슬링 추가)
    '골프, 축구, 테니스, 탁구, 헬스, 복싱, 레슬링', 
    # 30대 여성 (기존 유지)
    '골프, 요가, 필라테스, 수영, 테니스, 배드민턴, 헬스', 
    # 40대 남성 (기존 유지)
    '골프, 테니스, 축구, 헬스', 
    # 40대 여성 (기존 유지)
    '골프, 테니스, 수영, 러닝, 헬스', 
    # 50대 남성 (기존 유지)
    '골프, 테니스, 간이운동장, 당구, 게이트볼', 
    # 50대 여성 (기존 유지)
    '골프, 테니스, 간이운동장, 수영, 생활체육관', 
    # 60대 남성 (기존 유지)
    '간이운동장, 골프, 당구, 러닝', 
    # 60대 여성 (기존 유지)
    '간이운동장, 수영, 러닝', 
    # 70대 이상 남성 (기존 유지)
    '간이운동장', 
    # 70대 이상 여성 (기존 유지)
    '간이운동장', 
]

# 3. 연령대와 성별 조합 만들기
data = []
for age in ages:
    for g in gender:
        data.append([age, g])

# 4. ages와 gender로 먼저 데이터프레임 생성
# (변수명을 df4 -> sports_pref로 변경)
sports_pref = pd.DataFrame(data, columns=['ages', 'gender'])

# 5. 수정된 sports_nm 리스트를 새로운 열로 추가
sports_pref['sports_nm'] = sports_nm_combinations

# 6. 'id' 컬럼을 0번째 위치에 추가하고, 값은 인덱스(행 번호)로 설정
sports_pref.insert(0, 'id', sports_pref.index)

# 7. 결과 확인
print("--- [ sports_pref (연령/성별 선호 운동) - 수정본 ] ---")
print(f"(총 {len(sports_pref)}건의 조합)")
print(sports_pref.to_string()) # 모든 행 출력
# Out:
# --- [ sports_pref (연령/성별 선호 운동) - 수정본 ] ---
# (총 14건의 조합)
#     id    ages gender                        sports_nm
# 0    0     10대      남    축구, 태권도, 야구, 복싱, 풋살, 주짓수, 킥복싱
# 1    1     10대      여               태권도, 수영, 배드민턴, 합기도
# 2    2     20대      남      헬스, 축구, 당구, 골프, 볼링, 복싱, 주짓수
# 3    3     20대      여       헬스, 요가, 필라테스, 수영, 테니스, 킥복싱
# 4    4     30대      남     골프, 축구, 테니스, 탁구, 헬스, 복싱, 레슬링
# 5    5     30대      여  골프, 요가, 필라테스, 수영, 테니스, 배드민턴, 헬스
# 6    6     40대      남                  골프, 테니스, 축구, 헬스
# 7    7     40대      여              골프, 테니스, 수영, 러닝, 헬스
# 8    8     50대      남         골프, 테니스, 간이운동장, 당구, 게이트볼
# 9    9     50대      여        골프, 테니스, 간이운동장, 수영, 생활체육관
# 10  10     60대      남                간이운동장, 골프, 당구, 러닝
# 11  11     60대      여                    간이운동장, 수영, 러닝
# 12  12  70대 이상      남                            간이운동장
# 13  13  70대 이상      여                            간이운동장

# %%
df4 = sports_pref

# %% [markdown]
# ###  데이터베이스 업로드

# %%
from supabase import create_client, Client
import pandas as pd
import numpy as np

# ===================================================================
# 1. Supabase 접속 정보 (사용자가 제공한 정보)
# ===================================================================
url = "https://ydqqbjjsriadezcnkbmx.supabase.co"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InlkcXFiampzcmlhZGV6Y25rYm14Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3NTgyNDkzMjEsImV4cCI6MjA3MzgyNTMyMX0.U4-v7a40I2HUXJPb2oANFzqwA0QyEErTFEyrgqXdzeA"
table_name = "sports_pref"

# 이 코드 이전에 df4가 이미 생성되어 있다고 가정합니다.
# df4의 열: [id, ages, gender, sports_nm]

# ===================================================================
# 2. Supabase 업로드 (Upsert 방식)
# ===================================================================

try:
    # Supabase 클라이언트 생성
    supabase: Client = create_client(url, key)

    print(f"'{table_name}' 테이블에 업로드할 데이터 준비 중...")
    
    # [1단계: 업로드할 데이터 준비]
    
    # 1-1. (필수) Supabase는 NaN을 처리하지 못하므로 None으로 변경
    df_prepared = df4.replace([np.nan, np.inf, -np.inf], None)
    
    # 1-2. (필수) 'id' (PKey) 기준으로 *df4 내부의* 중복 제거
    #      (이걸 안 하면 upsert 배치 자체에서 오류가 날 수 있음)
    initial_count = len(df_prepared)
    df_prepared = df_prepared.drop_duplicates(subset=['id'], keep='first')
    removed_count = initial_count - len(df_prepared)
    
    if removed_count > 0:
        print(f"DataFrame 내부에서 'id' 중복 행 {removed_count}개를 제거했습니다.")

    # 1-3. 딕셔너리 형태로 변환
    records = df_prepared.to_dict(orient='records')

    # [2단계: 데이터 'Upsert' (Update or Insert) 실행]
    # 'id'를 기준으로 데이터가 있으면 업데이트, 없으면 삽입합니다.
    print(f"'{table_name}' 테이블에 {len(records)}개 데이터 'Upsert' 시도...")
    data, count = supabase.table(table_name).upsert(records).execute()
    
    print(f"✅ 성공! '{table_name}' 테이블에 데이터를 업로드/업데이트했습니다.")

except Exception as e:
    print(f"🚨 오류가 발생했습니다: {e}")
# Out:
# 'sports_pref' 테이블에 업로드할 데이터 준비 중...
# 'sports_pref' 테이블에 14개 데이터 'Upsert' 시도...
# ✅ 성공! 'sports_pref' 테이블에 데이터를 업로드/업데이트했습니다.
